# %% [markdown]
# Source Tutorial : https://youtu.be/0FtcHjI5lmw?si=KD9z8VHalKvpyKrj
#
# I modified it by try extracting Guru Gembul Youtube Channel Videos

# %%
'''
Youtube API google cloud: https://console.cloud.google.com/apis/api/youtube.googleapis.com/metrics?project=tribal-incline-421816
'''

dev = "AIzaSyD5D7c5yLaY4OmmgaVmqW5MsHRMZ8qfkh0"

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="mj96tIyLjW0",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']

  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="mj96tIyLjW0", maxResults=100, pageToken=nextPageToken)

  # Execute the next request.
  response = nextRequest.execute()

  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      447 non-null    object
#  1   updated_at  447 non-null    object
#  2   like_count  447 non-null    int64
#  3   text        447 non-null    object
#  4   public      447 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 14.5+ KB

# %% [markdown]
# At the current time i see the video, the number of comment is 729, but the extracted comment is only 447 which means this method does not extract all the comments, it only able to extract around 45-60% of the total

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'Q-_zSTSunQPCa96_DLXu387yaj0',
#  'id': 'UgxkW8b6N0uc5-Zaatp4AaABAg',
#  'snippet': {'channelId': 'UCL_D8_Oqnb_Icr3zRn9pVNw',
#   'videoId': 'mj96tIyLjW0',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'MVlSTliKYgJjr7djHLoTDK1MMXk',
#    'id': 'UgxkW8b6N0uc5-Zaatp4AaABAg',
#    'snippet': {'channelId': 'UCL_D8_Oqnb_Icr3zRn9pVNw',
#     'videoId': 'mj96tIyLjW0',
#     'textDisplay': 'Pernah lihat dokumenter Bule yg datang ke suku remote di Papua. Anaknya nangis kejer karena ngira si Bule ini mayat hidup. Karena si anak sering diceritain bapanya kalau nakal bakal didatengin mayat hidup yg berkulit pucat.',
#     'textOriginal': 'Pernah lihat dokumenter Bule yg datang ke suku remote di Papua. Anaknya nangis kejer karena ngira si Bule ini mayat hidup. Karena si anak sering diceritain bapanya kalau nakal bakal didatengin mayat hidup yg berkulit pucat.',
#     'authorDisplayName': '@Jelaidangulma',
# ...

# %%
df
# Out:
#                         author            updated_at  like_count  \
# 0         @dimasgatracgatra618  2024-09-24T05:17:41Z         153
# 1           @MariBelajar-dk6lb  2024-09-24T08:19:59Z           0
# 2                  @arisam4703  2024-09-24T08:18:41Z           0
# 3    @bandungonlinechannel3327  2024-09-24T08:18:30Z           0
# 4             @maspuadindayayi  2024-09-24T08:18:28Z           0
# ..                         ...                   ...         ...
# 442               @horazon3465  2024-09-24T05:01:22Z          13
# 443                  @hi-vo6xi  2024-09-24T05:01:20Z           1
# 444              @HeroHeru-w6b  2024-09-24T05:01:16Z           1
# 445           @amarmenonton496  2024-09-24T05:01:14Z           1
# 446          @dedisetiawan6198  2024-09-24T05:01:10Z           1
#
#                                                   text  public
# 0    pak guru mohon mengkoreksi perihal mic audiony...    True
# ...

# %%
df.head(10)
# Out:
#                       author            updated_at  like_count  \
# 0       @dimasgatracgatra618  2024-09-24T05:17:41Z         153
# 1         @MariBelajar-dk6lb  2024-09-24T08:19:59Z           0
# 2                @arisam4703  2024-09-24T08:18:41Z           0
# 3  @bandungonlinechannel3327  2024-09-24T08:18:30Z           0
# 4           @maspuadindayayi  2024-09-24T08:18:28Z           0
# 5        @SeghawonRahinopujo  2024-09-24T08:15:37Z           0
# 6           @Rizky.vidio_999  2024-09-24T08:15:32Z           0
# 7           @doniekaputra818  2024-09-24T08:15:24Z           0
# 8           @hanifmuismahmud  2024-09-24T08:15:03Z           0
# 9             @DjenArtficial  2024-09-24T08:14:16Z           0
#
#                                                 text  public
# 0  pak guru mohon mengkoreksi perihal mic audiony...    True
# 1  IDOLA GW YG BERANI MARAH MARAH LANGSUNG DIKAND...    True
# 2  mobil saja di mandikan kembang, itu salah satu...    True
# ...

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                    author            updated_at  like_count  \
# 0    @dimasgatracgatra618  2024-09-24T05:17:41Z         153
# 367  @dimasgatracgatra618  2024-09-24T05:17:41Z         153
# 420        @fayehsanullah  2024-09-24T05:03:50Z          90
# 439       @dwicahyono2219  2024-09-24T05:01:41Z          54
# 143        @channel-ov3gf  2024-09-24T06:39:17Z          19
# 387             @Febriery  2024-09-24T05:12:12Z          19
# 282           @zoro-cx8od  2024-09-24T05:43:59Z          19
# 442          @horazon3465  2024-09-24T05:01:22Z          13
# 200             @azuanism  2024-09-24T06:16:49Z          13
# 209     @saifulanam-pc5pq  2024-09-24T06:13:47Z          12
#
#                                                   text  public
# 0    pak guru mohon mengkoreksi perihal mic audiony...    True
# 367  pak guru mohon mengkoreksi perihal mic audiony...    True
# 420  Kaum pribumi takut sama Habib sih. Buktinya me...    True
# ...

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']

    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)

    # Execute the next request.
    response = nextRequest.execute()

    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2

# %%
df = getcomments('TLuWGpo1xbI')
df
# Out:
#                   author            updated_at  like_count  \
# 0            @gurugembul  2024-09-22T12:25:12Z         521
# 1     @kayabaakihiko4334  2024-09-24T08:29:57Z           0
# 2               @Vall_Ey  2024-09-24T08:15:54Z           0
# 3               @arve913  2024-09-24T08:15:34Z           0
# 4          @nartoken7082  2024-09-24T07:57:24Z           0
# ...                  ...                   ...         ...
# 2028     @mikkiwirawan11  2024-09-22T05:00:55Z           1
# 2029     @naganaries2687  2024-09-22T05:00:53Z           0
# 2030     @pikatkejam7097  2024-09-22T05:00:51Z           0
# 2031       @aguskhusaeni  2024-09-22T05:00:50Z           0
# 2032          @PriyoView  2024-09-22T05:00:45Z           1
#
#                                                    text     video_id  public
# 0     saya heran segininyakah warga kita?\n\nsaya ba...  TLuWGpo1xbI    True
# 1     bnyak contoh dari kefanatikan dari masyarakat ...  TLuWGpo1xbI    True
# ...

# %% [markdown]
# ## 2. For Loop for List of Video IDs

# %%
df = pd.DataFrame()
for i in ['TLuWGpo1xbI','KUul9E51AEc','rw2UtsPDNp8']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df
# Out:
#                   author            updated_at  like_count  \
# 0            @gurugembul  2024-09-22T12:25:12Z         521
# 1     @kayabaakihiko4334  2024-09-24T08:29:57Z           0
# 2               @Vall_Ey  2024-09-24T08:15:54Z           0
# 3               @arve913  2024-09-24T08:15:34Z           0
# 4          @nartoken7082  2024-09-24T07:57:24Z           0
# ...                  ...                   ...         ...
# 1663          @bolasulit  2024-09-16T05:01:19Z           1
# 1664       @rosyfury5395  2024-09-16T05:01:16Z           1
# 1665         @adnannn858  2024-09-16T05:01:16Z           2
# 1666        @bibiiyyycoy  2024-09-16T05:01:13Z           1
# 1667     @hafizhhasyhari  2024-09-16T05:01:10Z           2
#
#                                                    text     video_id  public
# 0     saya heran segininyakah warga kita?\n\nsaya ba...  TLuWGpo1xbI    True
# 1     bnyak contoh dari kefanatikan dari masyarakat ...  TLuWGpo1xbI    True
# ...

# %%
df['video_id'].value_counts()
# Out:
# video_id
# TLuWGpo1xbI    2033
# rw2UtsPDNp8    1668
# KUul9E51AEc    1429
# Name: count, dtype: int64
