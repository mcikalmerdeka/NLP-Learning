# %% [markdown]
# # Spacy Training : Word-Tagging

# %% [markdown]
# Documentation : https://spacy.io/usage#installation

# %%
# Download spacy library
# !pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.7.4-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Downloading thinc-8.2.3-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy)
#   Downloading typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.31.0)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.6.2-py3-none-any.whl.metadata (83 kB)
#      ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#      ---------------------------------------- 84.0/84.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.3)
# Collecting setuptools (from spacy)
#   Downloading setuptools-69.1.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.26.4)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.16.3-cp312-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading blis-0.7.11-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (2.1.5)
# Downloading spacy-3.7.4-cp312-cp312-win_amd64.whl (11.7 MB)
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.7 MB 5.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/11.7 MB 5.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/11.7 MB 5.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/11.7 MB 5.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.7 MB 6.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.7 MB 6.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.7 MB 6.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.7 MB 6.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.7 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.4/11.7 MB 3.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.7 MB 3.7 MB/s eta 0:00:03
#    ------ --------------------------------- 2.0/11.7 MB 3.6 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.7 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.7 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.7 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 2.2/11.7 MB 3.1 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.7 MB 3.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.7/11.7 MB 3.3 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/11.7 MB 3.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/11.7 MB 3.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.3/11.7 MB 3.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.5/11.7 MB 3.4 MB/s eta 0:00:03
#    ------------ --------------------------- 3.6/11.7 MB 3.4 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.7 MB 3.5 MB/s eta 0:00:03
#    ------------- -------------------------- 3.8/11.7 MB 3.4 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.7 MB 3.3 MB/s eta 0:00:03
#    -------------- ------------------------- 4.1/11.7 MB 3.3 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.7 MB 3.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.7 MB 3.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.6/11.7 MB 3.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.8/11.7 MB 3.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.0/11.7 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.1/11.7 MB 3.4 MB/s eta 0:00:02
#    ------------------ --------------------- 5.3/11.7 MB 3.4 MB/s eta 0:00:02
#    ------------------ --------------------- 5.5/11.7 MB 3.4 MB/s eta 0:00:02
#    ------------------- -------------------- 5.7/11.7 MB 3.4 MB/s eta 0:00:02
#    -------------------- ------------------- 5.9/11.7 MB 3.5 MB/s eta 0:00:02
#    -------------------- ------------------- 6.1/11.7 MB 3.5 MB/s eta 0:00:02
#    --------------------- ------------------ 6.2/11.7 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.5/11.7 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.7/11.7 MB 3.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.9/11.7 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.7 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 7.3/11.7 MB 3.6 MB/s eta 0:00:02
#    ------------------------- -------------- 7.5/11.7 MB 3.6 MB/s eta 0:00:02
#    -------------------------- ------------- 7.7/11.7 MB 3.7 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.7 MB 3.7 MB/s eta 0:00:02
#    --------------------------- ------------ 8.1/11.7 MB 3.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.4/11.7 MB 3.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.6/11.7 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.8/11.7 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 9.0/11.7 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.7 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.5/11.7 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.7 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.9/11.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.1/11.7 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.4/11.7 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.5/11.7 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.5/11.7 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.5/11.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.7/11.7 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.9/11.7 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.7 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  11.7/11.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 3.9 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl (39 kB)
# Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#    ---------------------------------------- 181.6/181.6 kB 5.5 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl (122 kB)
#    ---------------------------------------- 0.0/122.4 kB ? eta -:--:--
#    ---------------------------------------- 122.4/122.4 kB 3.6 MB/s eta 0:00:00
# Downloading pydantic-2.6.2-py3-none-any.whl (394 kB)
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    ------------------------ --------------- 245.8/394.9 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 394.9/394.9 kB 4.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.16.3-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB 8.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.9 MB 5.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/1.9 MB 6.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.9 MB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.9 MB 5.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 5.4 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB 3.1 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl (478 kB)
#    ---------------------------------------- 0.0/478.8 kB ? eta -:--:--
#    ------------------ --------------------- 225.3/478.8 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  471.0/478.8 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 478.8/478.8 kB 5.0 MB/s eta 0:00:00
# Downloading thinc-8.2.3-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB 8.6 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 6.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.4 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.4 MB/s eta 0:00:00
# Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.9 kB ? eta -:--:--
#    ---------------------------------------- 45.9/45.9 kB 2.2 MB/s eta 0:00:00
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB ? eta 0:00:00
# Downloading setuptools-69.1.1-py3-none-any.whl (819 kB)
#    ---------------------------------------- 0.0/819.3 kB ? eta -:--:--
#    ------------- -------------------------- 286.7/819.3 kB 5.9 MB/s eta 0:00:01
#    --------------------------- ------------ 563.2/819.3 kB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 778.2/819.3 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 819.3/819.3 kB 5.2 MB/s eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading blis-0.7.11-cp312-cp312-win_amd64.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.6 MB 6.3 MB/s eta 0:00:01
#    --- ------------------------------------ 0.6/6.6 MB 6.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.9/6.6 MB 6.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.2/6.6 MB 6.7 MB/s eta 0:00:01
#    -------- ------------------------------- 1.4/6.6 MB 6.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.7/6.6 MB 6.5 MB/s eta 0:00:01
#    ------------ --------------------------- 2.0/6.6 MB 6.3 MB/s eta 0:00:01
#    ------------- -------------------------- 2.3/6.6 MB 6.3 MB/s eta 0:00:01
#    --------------- ------------------------ 2.6/6.6 MB 6.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.9/6.6 MB 6.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.2/6.6 MB 6.3 MB/s eta 0:00:01
#    -------------------- ------------------- 3.4/6.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.7/6.6 MB 6.2 MB/s eta 0:00:01
#    ------------------------ --------------- 4.0/6.6 MB 6.3 MB/s eta 0:00:01
#    -------------------------- ------------- 4.4/6.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.7/6.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------------ --------- 5.0/6.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------------- -------- 5.3/6.6 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 5.6/6.6 MB 6.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.9/6.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 6.2/6.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  6.5/6.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 6.1 MB/s eta 0:00:00
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ---------------------------------------- 45.0/45.0 kB 2.2 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, setuptools, pydantic-core, murmurhash, langcodes, cloudpathlib, catalogue, blis, annotated-types, typer, srsly, pydantic, preshed, confection, weasel, thinc, spacy
# Successfully installed annotated-types-0.6.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.6.2 pydantic-core-2.16.3 setuptools-69.1.1 smart-open-6.4.0 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 typer-0.9.0 wasabi-1.1.2 weasel-0.3.4

# %%
# Download pre-trained model (if need to run in local)
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.1/12.8 MB 880.9 kB/s eta 0:00:15
#       --------------------------------------- 0.2/12.8 MB 1.4 MB/s eta 0:00:09
#      - -------------------------------------- 0.4/12.8 MB 2.0 MB/s eta 0:00:07
#      - -------------------------------------- 0.5/12.8 MB 2.2 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.8 MB 2.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/12.8 MB 2.6 MB/s eta 0:00:05
#      --- ------------------------------------ 1.0/12.8 MB 2.8 MB/s eta 0:00:05
#      --- ------------------------------------ 1.2/12.8 MB 2.9 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.3/12.8 MB 3.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.5/12.8 MB 3.3 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.8/12.8 MB 3.4 MB/s eta 0:00:04
#      ------ --------------------------------- 2.0/12.8 MB 3.6 MB/s eta 0:00:04
#      ------- -------------------------------- 2.3/12.8 MB 3.7 MB/s eta 0:00:03
#      ------- -------------------------------- 2.5/12.8 MB 3.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.5/12.8 MB 3.8 MB/s eta 0:00:03
#      -------- ------------------------------- 2.7/12.8 MB 3.8 MB/s eta 0:00:03
#      --------- ------------------------------ 3.0/12.8 MB 3.9 MB/s eta 0:00:03
#      --------- ------------------------------ 3.2/12.8 MB 3.9 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.4/12.8 MB 3.9 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.6/12.8 MB 4.0 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.8/12.8 MB 4.1 MB/s eta 0:00:03
#      ------------ --------------------------- 4.1/12.8 MB 4.1 MB/s eta 0:00:03
#      ------------- -------------------------- 4.3/12.8 MB 4.3 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 4.3 MB/s eta 0:00:02
#      --------------- ------------------------ 4.8/12.8 MB 4.3 MB/s eta 0:00:02
#      --------------- ------------------------ 5.1/12.8 MB 4.4 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.3/12.8 MB 4.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 4.5 MB/s eta 0:00:02
#      ------------------ --------------------- 5.8/12.8 MB 4.5 MB/s eta 0:00:02
#      ------------------ --------------------- 6.0/12.8 MB 4.6 MB/s eta 0:00:02
#      ------------------- -------------------- 6.2/12.8 MB 4.6 MB/s eta 0:00:02
#      -------------------- ------------------- 6.5/12.8 MB 4.6 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.8 MB 4.6 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 4.7 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.1/12.8 MB 4.7 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.3/12.8 MB 4.7 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.5/12.8 MB 4.7 MB/s eta 0:00:02
#      ------------------------ --------------- 7.8/12.8 MB 4.7 MB/s eta 0:00:02
#      ------------------------- -------------- 8.0/12.8 MB 4.7 MB/s eta 0:00:02
#      ------------------------- -------------- 8.3/12.8 MB 4.8 MB/s eta 0:00:01
#      -------------------------- ------------- 8.5/12.8 MB 4.8 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 4.8 MB/s eta 0:00:01
#      --------------------------- ------------ 8.8/12.8 MB 4.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.1/12.8 MB 4.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 4.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.5/12.8 MB 4.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.6/12.8 MB 4.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 4.8 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 4.8 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 4.8 MB/s eta 0:00:01
#      -------------------------------- ------- 10.4/12.8 MB 5.0 MB/s eta 0:00:01
#      --------------------------------- ------ 10.6/12.8 MB 5.0 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/12.8 MB 5.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 5.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.2/12.8 MB 5.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.4/12.8 MB 5.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 5.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 5.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 5.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 5.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 5.1 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.2)
# Requirement already satisfied: jinja2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cikal merdeka\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Import library and load pre-trained model
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Processing sentence
sentence = "President Jokowi will complete his duties as the President of the Republic of Indonesia on October 20, 2024" #initiate sentence that will be processed
doc = nlp(sentence) #save the sentence in an object called doc

# %%
# Check text only
for token in doc :
    print(token)
# Out:
# President
# Jokowi
# will
# complete
# his
# duties
# as
# the
# President
# of
# the
# Republic
# of
# Indonesia
# on
# October
# 20
# ,
# 2024

# %%
#Check the language input
for token in doc :
    print(token.lang_)
# Out:
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en

# %% [markdown]
# Note that unfortunately Indonesian language is still not supported as in 27 February 2024. Check available languages in : https://spacy.io/usage/models#languages

# %% [markdown]
# Check all the useful methods that can be done for the token in the documentation : https://spacy.io/usage/linguistic-features

# %%
# Seeing text, token, and position in sentence
for token in doc:
    print("{0}\t{1}\t{2} ".format(token.text,token.idx,token.pos_))
# Out:
# President	0	PROPN
# Jokowi	10	PROPN
# will	17	AUX
# complete	22	VERB
# his	31	PRON
# duties	35	NOUN
# as	42	ADP
# the	45	DET
# President	49	PROPN
# of	59	ADP
# the	62	DET
# Republic	66	PROPN
# of	75	ADP
# Indonesia	78	PROPN
# on	88	ADP
# October	91	PROPN
# 20	99	NUM
# ,	101	PUNCT
# 2024	103	NUM

# %%
# Seeing Named-entity
from spacy import displacy
displacy.render(docs=doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jokowi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will complete his duties as the President of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Republic of Indonesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 20, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %%
# Seeing dependency tree
displacy.render(docs=doc, style='dep', jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7cbe5d73575b46ac86c3ea127f70e15f-0" class="displacy" width="1850" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Jokowi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">complete</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">duties</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">Republic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">Indonesia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">October</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">20,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">2024</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-1" stroke-width="2px" d="M170,202.0 C170,102.0 340.0,102.0 340.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-2" stroke-width="2px" d="M270,202.0 C270,152.0 335.0,152.0 335.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-3" stroke-width="2px" d="M470,202.0 C470,152.0 535.0,152.0 535.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,204.0 L462,192.0 478,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-4" stroke-width="2px" d="M370,202.0 C370,102.0 540.0,102.0 540.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M540.0,204.0 L548.0,192.0 532.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7cbe5d73575b46ac86c3ea127f70e15f-0-5" stroke-width="2px" d="M370,202.0 C370,52.0 645.0,52.0 645.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href
